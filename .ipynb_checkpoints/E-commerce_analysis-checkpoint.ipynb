# %% [markdown]
# # Title
# ## link  - https://archive.ics.uci.edu/ml/datasets/online%2Bretail

# %% [markdown]
# ### intro

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read the main data with more than 500000 rows
main_data = pd.read_excel('./Dataset-online-retail.xlsx')

# %%
main_data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...

# %%
main_data.tail(10)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541899    581587     22726       ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730       ALARM CLOCK BAKELIKE IVORY         4
# 541901    581587     22367  CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629              SPACEBOY LUNCH BOX         12
# 541903    581587     23256      CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541899 2011-12-09 12:50:00       3.75     12680.0  France
# 541900 2011-12-09 12:50:00       3.75     12680.0  France
# ...

# %%
# check the shape of the dateframe
main_data.shape
# Out:
# (541909, 8)

# %%
# check the data types in the dateframe
main_data.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
#check for nan
nan_df = main_data[main_data.isna().any(axis=1)]
nan_df
# We can see that there are 135080 rows in which NaN appears.
# Because of the significant numbers of rows, I will not drop the rows that have some values stored as NaN
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# I will drop only the rows that have NaN values in every column.
main_data = main_data.dropna(how="all")
main_data.shape

# So, it seems that trete were no such rows, but now, we know it for sure.
# Out:
# (541909, 8)

# %%
# check the datetime format
main_data.head(10)['InvoiceDate']
# Out:
# 0   2010-12-01 08:26:00
# 1   2010-12-01 08:26:00
# 2   2010-12-01 08:26:00
# 3   2010-12-01 08:26:00
# 4   2010-12-01 08:26:00
# 5   2010-12-01 08:26:00
# 6   2010-12-01 08:26:00
# 7   2010-12-01 08:28:00
# 8   2010-12-01 08:28:00
# 9   2010-12-01 08:34:00
# Name: InvoiceDate, dtype: datetime64[ns]

# %%
# fist 6 monts of sales in 2011 
h1_2011 = main_data[(main_data['InvoiceDate'] >= '2011-01-01 00:00:00') & (main_data['InvoiceDate'] < '2011-07-01 00:00:00')]
h1_2011
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 42481     539993     22386       JUMBO BAG PINK POLKADOT        10
# 42482     539993     21499            BLUE POLKADOT WRAP        25
# 42483     539993     21498           RED RETROSPOT WRAP         25
# 42484     539993     22379      RECYCLING BAG RETROSPOT          5
# 42485     539993     20718     RED RETROSPOT SHOPPER BAG        10
# ...          ...       ...                           ...       ...
# 245898    558637     22032  BOTANICAL LILY GREETING CARD        12
# 245899    558637     22028  PENNY FARTHING BIRTHDAY CARD        12
# 245900    558637     22033  BOTANICAL ROSE GREETING CARD        12
# 245901    558637     22029        SPACEBOY BIRTHDAY CARD        12
# 245902    558637     22024    RAINY LADIES BIRTHDAY CARD        12
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 42481  2011-01-04 10:00:00       1.95     13313.0  United Kingdom
# ...

# %%
# second half 6 monts of sales in 2011
h2_2011 = main_data[(main_data['InvoiceDate'] >= '2011-07-01 00:00:00') & (main_data['InvoiceDate'] < '2011-12-31 00:00:00')]
h2_2011

#  if you want to extract this file as a new excel file, just uncomment the following and re-run the cell
# h2_2011.to_excel('Sales_second_half_of_2011.xlsx')
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 245903    558638     84836      ZINC METAL HEART DECORATION        12
# 245904    558638     71459   HANGING JAM JAR T-LIGHT HOLDER        24
# 245905    558638     22784            LANTERN CREAM GAZEBO          3
# 245906    558638     23145   ZINC T-LIGHT HOLDER STAR LARGE        12
# 245907    558638     22674    FRENCH TOILET SIGN BLUE METAL        12
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
canceled_h1 = []
sold_h1 = []
for record in h1_2011['InvoiceNo']:
    if 'C' in str(record):
        canceled_h1.append(record)
    else:
        sold_h1.append(record)

# %%
# count the canceled orders during the first half of 2011
sum_canceled_h1 = len(canceled_h1)
sum_canceled_h1
# Out:
# 3766

# %%
# Count the sales during the first half of 2011
sum_sales_h1 = len(sold_h1)
sum_sales_h1
# Out:
# 199656

# %%
# Pie Chart of Sales vs Canceled during the first half of 2011
labels = 'Sales', 'Canceled'
sizes = [sum_sales_h1, sum_canceled_h1]
fig1, ax1 = plt.subplots()

ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
canceled_h2 = []
sold_h2 = []
for record in h2_2011['InvoiceNo']:
    if 'C' in str(record):
        canceled_h2.append(record)
    else:
        sold_h2.append(record)

# %%
# count the canceled orders during the second half of 2011
sum_canceled_h2 = len(canceled_h2)
sum_canceled_h2
# Out:
# 4794

# %%
# Count the sales during the second half of 2011
sum_sales_h2 = len(sold_h2)
sum_sales_h2
# Out:
# 291212

# %%
# Pie Chart of Sales vs Canceled during the second half of 2011
labels = 'Sales', 'Canceled'
sizes = [sum_sales_h2, sum_canceled_h2]
fig1, ax1 = plt.subplots()

ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Pie Chart of Sales during the first half of 2011 vs Sales during the second half of 2011

labels = 'Sales H1', 'Sales H2'
sizes = [sum_sales_h1, sum_sales_h2]
fig1, ax1 = plt.subplots()

ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# #  top 6 sold products

# %% [markdown]
# ###  fist 6 monts

# %%
grouped_by_stockcode = main_data.groupby('StockCode').sum()
grouped_by_stockcode
# Out:
#               Quantity  UnitPrice  CustomerID
# StockCode
# 10002             1037      77.15    723842.0
# 10080              495       9.04    333014.0
# 10120              193       6.30    484879.0
# 10125             1296      80.81    976545.0
# 10133             2775     129.16   1942666.0
# ...                ...        ...         ...
# gift_0001_20        20     150.38         0.0
# gift_0001_30        37     175.53         0.0
# gift_0001_40         3     100.70         0.0
# gift_0001_50         4     167.56         0.0
# m                    1       2.55         0.0
#
# [4070 rows x 3 columns]

# %%
grouped_by_stockcode['Quantity'].max()
# Out:
# 56450

# %%
sorted_by_qty = grouped_by_stockcode.sort_values(by=['Quantity'], ascending=False)
sorted_by_qty = sorted_by_qty.drop(columns=['UnitPrice', 'CustomerID'])
top_six_products = sorted_by_qty.head(6)

# %%
top_six_products
# Out:
#            Quantity
# StockCode
# 22197         56450
# 84077         53847
# 85099B        47363
# 85123A        38830
# 84879         36221
# 21212         36039

# %%
top_six_products = top_six_products.reset_index()

# %%
top_six_products
# Out:
#   StockCode  Quantity
# 0     22197     56450
# 1     84077     53847
# 2    85099B     47363
# 3    85123A     38830
# 4     84879     36221
# 5     21212     36039

# %%
top_six_products['StockCode']
# Out:
# 0     22197
# 1     84077
# 2    85099B
# 3    85123A
# 4     84879
# 5     21212
# Name: StockCode, dtype: object

# %%
top_six_products['Quantity']
# Out:
# 0    56450
# 1    53847
# 2    47363
# 3    38830
# 4    36221
# 5    36039
# Name: Quantity, dtype: int64

# %%
# Visualise the sales of top six products to see if there are big differences

list_stocks = list(top_six_products['StockCode'])
list_qty = list(top_six_products['Quantity'])

labels = list_stocks
sizes = list_qty
fig1, ax1 = plt.subplots()

ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Find the with most sales to create an audience

def top_country(dataframe, num_top_country):
    
    data_grouped_by_county = dataframe.groupby('Country').sum()
    data_grouped_by_county = data_grouped_by_county.sort_values(by=['Quantity'], ascending=False).head(num_top_country)
    return data_grouped_by_county

# %%
top_5_country_h1 = top_country(h1_2011,5)
top_5_country_h1
# Out:
#                 Quantity   UnitPrice    CustomerID
# Country
# United Kingdom   1565505  879284.751  2.060079e+09
# Netherlands        93041    2964.410  1.679635e+07
# Australia          49795    2144.740  7.947406e+06
# EIRE               48049   25462.800  3.609120e+07
# Germany            46655   13519.250  4.679405e+07

# %%
# Plot the top 5 countries by sales in the second 6 mths of 2011

plt.bar(list(top_5_country_h1.index), top_5_country_h1['Quantity'])
plt.xticks(list(top_5_country_h1.index), rotation='vertical', size=9)
plt.xlabel('Country')
plt.ylabel('Sales in USD ($)')
plt.title('Top 5 countries by sales in the first 6 mths of 2011')
plt.yticks([100000, 500000, 1000000, 1500000, 2000000])

plt.show()

# %%
# since hives has significantly more sales than other countries let's remove it to have a better view of them
# Plot the top 5 countries by sales in the second 6 mths of 2011 without UK

top_4_country_h1_excl_uk = top_5_country_h1.iloc[1: , :]

plt.bar(list(top_4_country_h1_excl_uk.index), top_4_country_h1_excl_uk['Quantity'])
plt.xticks(list(top_4_country_h1_excl_uk.index))
plt.xlabel('Country')
plt.ylabel('Sales in USD ($)')
plt.title('Top 4 countries excl. UK by sales in the first 6 mths of 2011')
plt.yticks([20000, 40000, 60000, 80000, 100000])

plt.show()

# %%
top_3_country_h2 = top_country(h2_2011,3)
top_3_country_h2
# Out:
#                 Quantity     UnitPrice    CustomerID
# Country
# United Kingdom   2400223  1.114508e+06  3.180160e+09
# Netherlands       100276  3.366450e+03  1.634338e+07
# EIRE               89207  2.101126e+04  6.894145e+07

# %%
# Plot the top 3 countries by sales in the second 6 mths of 2011

plt.bar(list(top_3_country_h2.index), top_3_country_h2['Quantity'])
plt.xticks(list(top_3_country_h2.index))
plt.xlabel('Country')
plt.ylabel('Sales')
plt.title('Top 3 countries by sales in the second 6 mths of 2011')
plt.yticks([100000, 500000, 1000000, 1500000, 2000000, 2500000])

plt.show()

# %%
# Find the key clients

def top_clients(dataframe, num_top_clients):
    data_sorted_by_clients = dataframe.groupby('CustomerID').sum()
    data_sorted_by_clients = data_sorted_by_clients.sort_values(by='Quantity', ascending=False).head(num_top_clients)
    return data_sorted_by_clients

# %%
# since the UK has significant numbers of sales that

# %%
top_clients(h1_2011,2)
# Out:
#             Quantity  UnitPrice
# CustomerID
# 14646.0        90704    2248.45
# 12415.0        47110    1397.75

# %%
top_clients(h2_2011,11)
# Out:
#             Quantity  UnitPrice
# CustomerID
# 14646.0        99301    3006.92
# 14911.0        53943   15454.29
# 17450.0        46003    1231.45
# 18102.0        40102    4323.63
# 17511.0        35254    1319.64
# 16684.0        31626     343.60
# 14156.0        31072    3969.25
# 12415.0        30132    1102.07
# 13694.0        24529     662.97
# 12931.0        20307     155.64
# 14298.0        20241    1142.59

# %% [markdown]
# ### top month for sales during the first half of 2011

# %%
h1_2011.head(5)
# Out:
#       InvoiceNo StockCode                Description  Quantity  \
# 42481    539993     22386    JUMBO BAG PINK POLKADOT        10
# 42482    539993     21499         BLUE POLKADOT WRAP        25
# 42483    539993     21498        RED RETROSPOT WRAP         25
# 42484    539993     22379   RECYCLING BAG RETROSPOT          5
# 42485    539993     20718  RED RETROSPOT SHOPPER BAG        10
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 42481 2011-01-04 10:00:00       1.95     13313.0  United Kingdom
# 42482 2011-01-04 10:00:00       0.42     13313.0  United Kingdom
# 42483 2011-01-04 10:00:00       0.42     13313.0  United Kingdom
# 42484 2011-01-04 10:00:00       2.10     13313.0  United Kingdom
# 42485 2011-01-04 10:00:00       1.25     13313.0  United Kingdom

# %%
# Make a function to generate a Month column by providing a dataframe

def make_column_with_inv_month(dataframe):
    dataframe['InvoiceDate'] = dataframe['InvoiceDate'].astype(str)
    dataframe['Month'] = dataframe['InvoiceDate'].str[5:7].astype(int)
    return dataframe

# %%
make_column_with_inv_month(h1_2011)
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 42481     539993     22386       JUMBO BAG PINK POLKADOT        10
# 42482     539993     21499            BLUE POLKADOT WRAP        25
# 42483     539993     21498           RED RETROSPOT WRAP         25
# 42484     539993     22379      RECYCLING BAG RETROSPOT          5
# 42485     539993     20718     RED RETROSPOT SHOPPER BAG        10
# ...          ...       ...                           ...       ...
# 245898    558637     22032  BOTANICAL LILY GREETING CARD        12
# 245899    558637     22028  PENNY FARTHING BIRTHDAY CARD        12
# 245900    558637     22033  BOTANICAL ROSE GREETING CARD        12
# 245901    558637     22029        SPACEBOY BIRTHDAY CARD        12
# 245902    558637     22024    RAINY LADIES BIRTHDAY CARD        12
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  Month
# 42481   2011-01-04 10:00:00       1.95     13313.0  United Kingdom      1
# ...

# %%
make_column_with_inv_month(h2_2011)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 245903    558638     84836      ZINC METAL HEART DECORATION        12
# 245904    558638     71459   HANGING JAM JAR T-LIGHT HOLDER        24
# 245905    558638     22784            LANTERN CREAM GAZEBO          3
# 245906    558638     23145   ZINC T-LIGHT HOLDER STAR LARGE        12
# 245907    558638     22674    FRENCH TOILET SIGN BLUE METAL        12
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  Month
# ...

# %%
# Make a function to generate a Sales column which consist of by providing a dataframe
# The Sales column consists of the quantity of product sold multiplied by its unit price

def make_column_sales(dataframe):
    dataframe['Sales'] = dataframe['Quantity'] * dataframe['UnitPrice']
    dataframe['Sales'] = dataframe['Sales'].astype(float)
    return dataframe

# %%
make_column_sales(h1_2011)
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 42481     539993     22386       JUMBO BAG PINK POLKADOT        10
# 42482     539993     21499            BLUE POLKADOT WRAP        25
# 42483     539993     21498           RED RETROSPOT WRAP         25
# 42484     539993     22379      RECYCLING BAG RETROSPOT          5
# 42485     539993     20718     RED RETROSPOT SHOPPER BAG        10
# ...          ...       ...                           ...       ...
# 245898    558637     22032  BOTANICAL LILY GREETING CARD        12
# 245899    558637     22028  PENNY FARTHING BIRTHDAY CARD        12
# 245900    558637     22033  BOTANICAL ROSE GREETING CARD        12
# 245901    558637     22029        SPACEBOY BIRTHDAY CARD        12
# 245902    558637     22024    RAINY LADIES BIRTHDAY CARD        12
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  Month  \
# 42481   2011-01-04 10:00:00       1.95     13313.0  United Kingdom      1
# ...

# %%
make_column_sales(h2_2011)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 245903    558638     84836      ZINC METAL HEART DECORATION        12
# 245904    558638     71459   HANGING JAM JAR T-LIGHT HOLDER        24
# 245905    558638     22784            LANTERN CREAM GAZEBO          3
# 245906    558638     23145   ZINC T-LIGHT HOLDER STAR LARGE        12
# 245907    558638     22674    FRENCH TOILET SIGN BLUE METAL        12
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  Month  \
# ...

# %% [markdown]
# #### What was the best month for sales? How moch was earned that month?

# %%
# function to calculate the sales per month
def sales_per_month(dataframe):
    return dataframe.groupby('Month').sum()

# %%
sales_per_month(h1_2011)
# Out:
#        Quantity   UnitPrice   CustomerID       Sales
# Month
# 1        308966  172752.800  331919771.0  560000.260
# 2        277989  127448.770  311780860.0  498062.650
# 3        351872  171486.510  422329758.0  683267.080
# 4        289098  129164.961  354119428.0  493207.121
# 5        380391  190685.460  440008786.0  723333.510
# 6        341623  200717.340  426470991.0  691123.120

# %%
sales_per_month(h2_2011)
# Out:
#        Quantity   UnitPrice    CustomerID        Sales
# Month
# 7        391116  171906.791  4.209226e+08   681300.111
# 8        406199  150385.680  4.219478e+08   682680.510
# 9        549817  199235.212  6.229373e+08  1019687.622
# 10       570532  263434.090  7.727017e+08  1070704.670
# 11       740286  327149.850  1.007384e+09  1461756.250
# 12       226333  133915.660  2.702551e+08   433668.010

# %% [markdown]
# #### for this analysis it will be better to see the data for the whole year 2011

# %%
# sales in 2011 
y_2011 = main_data[(main_data['InvoiceDate'] >= '2011-01-01 00:00:00') & (main_data['InvoiceDate'] < '2011-12-31 00:00:00')]
y_2011
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 42481     539993     22386          JUMBO BAG PINK POLKADOT        10
# 42482     539993     21499               BLUE POLKADOT WRAP        25
# 42483     539993     21498              RED RETROSPOT WRAP         25
# 42484     539993     22379         RECYCLING BAG RETROSPOT          5
# 42485     539993     20718        RED RETROSPOT SHOPPER BAG        10
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# lets generate the "Month" and "Sales" columns
make_column_with_inv_month(y_2011)
make_column_sales(y_2011)
y_2011
# Out:
# <ipython-input-107-871ecf4358e6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['InvoiceDate'] = dataframe['InvoiceDate'].astype(str)
# <ipython-input-107-871ecf4358e6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Month'] = dataframe['InvoiceDate'].str[5:7].astype(int)
# <ipython-input-111-2f80a3c21345>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# so now let's see the sales per month for the whole 2011
sales_2011 = sales_per_month(y_2011)
sales_2011
# Out:
#        Quantity   UnitPrice    CustomerID        Sales
# Month
# 1        308966  172752.800  3.319198e+08   560000.260
# 2        277989  127448.770  3.117809e+08   498062.650
# 3        351872  171486.510  4.223298e+08   683267.080
# 4        289098  129164.961  3.541194e+08   493207.121
# 5        380391  190685.460  4.400088e+08   723333.510
# 6        341623  200717.340  4.264710e+08   691123.120
# 7        391116  171906.791  4.209226e+08   681300.111
# 8        406199  150385.680  4.219478e+08   682680.510
# 9        549817  199235.212  6.229373e+08  1019687.622
# 10       570532  263434.090  7.727017e+08  1070704.670
# 11       740286  327149.850  1.007384e+09  1461756.250
# 12       226333  133915.660  2.702551e+08   433668.010

# %%
# Out:
# 12

# %% [markdown]
# #### As you can see December is the month with less sales, but we have to consider that the prvided data includes the sales to 2011-12-09 12:50:00. So, we are missing 22 days of this month. Since we are using functional progaming, there won't be a problem to re-call the functions over the provided when we have the whole month December.

# %% [markdown]
# ### Let's plot the sales during 2011

# %%
# function to plot the sales for provided dataframe it has column "Sales"
# please note that in order for this function to work, we need to global import matplotlib.pyplot as plt


def plot_sales(dataframe):
#     calculate how much months are provided in the dataframe
    months_range = list(range(1,len(dataframe['Sales'])+1))
    
#     plot
    plt.bar(months_range, dataframe['Sales'])
    plt.xlabel('Month number')
    plt.ylabel('Sales in USD ($)')
    plt.title('Sales per month')
    plt.xticks(months_range)
    plt.show()

# %%
plot_sales(sales_2011)

# %%
h1_2011
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 42481     539993     22386       JUMBO BAG PINK POLKADOT        10
# 42482     539993     21499            BLUE POLKADOT WRAP        25
# 42483     539993     21498           RED RETROSPOT WRAP         25
# 42484     539993     22379      RECYCLING BAG RETROSPOT          5
# 42485     539993     20718     RED RETROSPOT SHOPPER BAG        10
# ...          ...       ...                           ...       ...
# 245898    558637     22032  BOTANICAL LILY GREETING CARD        12
# 245899    558637     22028  PENNY FARTHING BIRTHDAY CARD        12
# 245900    558637     22033  BOTANICAL ROSE GREETING CARD        12
# 245901    558637     22029        SPACEBOY BIRTHDAY CARD        12
# 245902    558637     22024    RAINY LADIES BIRTHDAY CARD        12
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  Month  \
# 42481   2011-01-04 10:00:00       1.95     13313.0  United Kingdom      1
# ...

# %%
sales_per_month_h1_2011 = sales_per_month(h1_2011)
sales_per_month_h1_2011
# Out:
#        Quantity   UnitPrice   CustomerID       Sales
# Month
# 1        308966  172752.800  331919771.0  560000.260
# 2        277989  127448.770  311780860.0  498062.650
# 3        351872  171486.510  422329758.0  683267.080
# 4        289098  129164.961  354119428.0  493207.121
# 5        380391  190685.460  440008786.0  723333.510
# 6        341623  200717.340  426470991.0  691123.120

# %%
plot_sales(sales_per_month_h1_2011)

# %% [markdown]
# ### What time should we display advertisments to maximize likelihood of customer's buying products?

# %%
main_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
#ensure that the invoice date column is in datetime format

main_data['InvoiceDate'] = pd.to_datetime(main_data['InvoiceDate'])
